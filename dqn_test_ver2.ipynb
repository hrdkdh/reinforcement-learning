# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
df_kodex = pd.read_excel("crawled_data_kodex.xlsx")
df_kodex = df_kodex.loc[:, ["date", "KODEX_CLS", "KODEX_OPN", "KODEX_GAP"]]
df_kodex
# Out:
#             date  KODEX_CLS  KODEX_OPN  KODEX_GAP
# 0     2015-10-12      20215      20250         35
# 1     2015-10-13      20195      20175        -20
# 2     2015-10-14      20070      20150         80
# 3     2015-10-15      20315      20235        -80
# 4     2015-10-16      20285      20315         30
# ...          ...        ...        ...        ...
# 1638  2022-04-04      28280      28060       -220
# 1639  2022-04-05      28255      28340         85
# 1640  2022-04-06      28010      28055         45
# 1641  2022-04-07      27660      27860        200
# 1642  2022-04-08      27670      27710         40
#
# [1643 rows x 4 columns]

# %%
df_kodex_inv = pd.read_excel("crawled_data_kodex_inv.xlsx")
df_kodex_inv = df_kodex_inv.loc[:, ["date", "KODEX_INV_CLS", "KODEX_INV_OPN", "KODEX_INV_GAP"]]
df_kodex_inv
# Out:
#             date  KODEX_INV_CLS  KODEX_INV_OPN  KODEX_INV_GAP
# 0     2013-10-10           7555           7535            -20
# 1     2013-10-11           7420           7485             65
# 2     2013-10-14           7425           7425              0
# 3     2013-10-15           7365           7385             20
# 4     2013-10-16           7360           7355             -5
# ...          ...            ...            ...            ...
# 2501  2022-04-04           4275           4315             40
# 2502  2022-04-05           4280           4260            -20
# 2503  2022-04-06           4325           4310            -15
# 2504  2022-04-07           4385           4360            -25
# 2505  2022-04-08           4385           4375            -10
#
# [2506 rows x 4 columns]

# %%
df_kospi = pd.read_excel("crawled_data.xlsx")
df_kospi.dropna(inplace=True)
df_kospi.sort_values("date", inplace=True)
df_kospi.reset_index(drop=True, inplace=True)
df_kospi = df_kospi.iloc[:, 1:6]
df_kospi
# Out:
#             date    KOSPI  KOSPI_START  KOSPI_HIGH  KOSPI_LOW
# 0     2010-05-13  1694.58      1683.76     1700.00    1682.91
# 1     2010-05-14  1695.63      1685.75     1699.59    1677.44
# 2     2010-05-17  1651.51      1668.57     1673.01    1644.71
# 3     2010-05-18  1643.24      1662.31     1663.15    1629.35
# 4     2010-05-19  1630.08      1621.32     1630.31    1601.54
# ...          ...      ...          ...         ...        ...
# 2840  2022-04-04  2757.90      2729.86     2758.38    2722.45
# 2841  2022-04-05  2759.20      2765.50     2769.18    2750.50
# 2842  2022-04-06  2735.03      2739.07     2747.85    2730.66
# 2843  2022-04-07  2695.86      2714.70     2718.50    2693.36
# 2844  2022-04-08  2700.39      2706.64     2712.00    2685.52
#
# [2845 rows x 5 columns]

# %%
#2021년 데이터로 학습한다.
df = df_kospi.merge(df_kodex, how="right", on="date")
df = df.merge(df_kodex_inv, how="left", on="date")
df.dropna(inplace=True)
df.sort_values("date", inplace=True)
df.reset_index(drop=True, inplace=True)

df["date"] = pd.to_datetime(df["date"])
df = df[(df["date"] >= "2021-01-01") & (df["date"] <= "2021-12-31")]
df.reset_index(drop=True, inplace=True)
df
# Out:
#           date    KOSPI  KOSPI_START  KOSPI_HIGH  KOSPI_LOW  KODEX_CLS  \
# 0   2021-01-04  2944.45      2874.50     2946.54    2869.11      29850
# 1   2021-01-05  2990.57      2943.67     2990.57    2921.84      30340
# 2   2021-01-06  2968.21      2993.34     3027.16    2961.37      30195
# 3   2021-01-07  3031.68      2980.75     3055.28    2980.75      30830
# 4   2021-01-08  3152.18      3040.11     3161.11    3040.11      31955
# ..         ...      ...          ...         ...        ...        ...
# 235 2021-12-23  2998.17      2998.02     3000.70    2980.91      30155
# 236 2021-12-27  2999.55      3013.94     3017.31    2999.30      30235
# 237 2021-12-28  3020.24      3006.77     3020.29    2991.55      30445
# 238 2021-12-29  2993.29      3002.90     3007.72    2988.67      30545
# 239 2021-12-30  2977.65      2999.75     3005.36    2975.74      30325
#
#      KODEX_OPN  KODEX_GAP  KODEX_INV_CLS  KODEX_INV_OPN  KODEX_INV_GAP
# 0        29320       -530         4145.0         4260.0          115.0
# 1        29790       -550         4090.0         4175.0           85.0
# 2        30490        295         4125.0         4080.0          -45.0
# 3        30515       -315         4030.0         4075.0           45.0
# 4        31185       -770         3850.0         3980.0          130.0
# ..         ...        ...            ...            ...            ...
# 235      30200         45         4005.0         4015.0           10.0
# 236      30365        130         4000.0         3975.0          -25.0
# 237      30250       -195         3980.0         3990.0           10.0
# 238      30560         15         3980.0         3965.0          -15.0
# 239      30555        230         4005.0         3975.0          -30.0
#
# [240 rows x 11 columns]

# %%
state_list = []
for idx in range(len(df)):
    if idx > 59:
        this_mat = df.iloc[idx-60:idx, 0:5].to_numpy()
        for col_idx in range(1, this_mat.shape[1]):
            this_arr = this_mat[:, col_idx]
            max_val = max(this_arr)
            min_val = min(this_arr)
            for row_idx, val in enumerate(this_arr):
                new_val = (val - min_val) / (max_val - min_val)
                this_mat[row_idx, col_idx] = new_val
        state_list.append(this_mat)

state_list = np.array(state_list)
state_list.shape

#6개열 : date, KOSPI, KOSPI_START, KOSPI_HIGH, KOSPI_LOW, CAPITAL
# Out:
# (180, 60, 5)

# %%
action_names = ["KDX매수", "KDI매수"]

# %%
model_pred = tf.keras.Sequential([
    tf.keras.layers.Input((state_list.shape[1]*(state_list.shape[2]-1))+1),
    tf.keras.layers.Dense(units=128, activation="relu"),
    tf.keras.layers.Dense(units=128, activation="relu"),
    tf.keras.layers.Dense(units=128, activation="relu"),
    tf.keras.layers.Dense(units=128, activation="relu"),
    tf.keras.layers.Dense(units=128, activation="relu"),
    tf.keras.layers.Dense(units=2, activation="softmax")
])
model_pred.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss="mse", 
              metrics=["mae", "mse"])

model_pred.summary()
model_pred.save("model_pred.h5")
model_q = tf.keras.models.load_model("model_pred.h5")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               30976
#
#  dense_13 (Dense)            (None, 128)               16512
#
#  dense_14 (Dense)            (None, 128)               16512
#
#  dense_15 (Dense)            (None, 128)               16512
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dense_17 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 97,282
# Trainable params: 97,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import clear_output

dis = .5 #discounted reward를 위해
profit_rate_goal = 1.5 #terminal 목표를 수익율 150%로 설정한다.
update_period = 120 #스테이지 120회당 1번씩 pred 모델의 웨이트를 업데이트 한다.
copy_period = 180
cnt_for_update = 0
cnt_for_copy = 0
episodes = 5000
batch_buffer = []
reward_list = []
result = []
temp_var = False
for episode in range(1, episodes+1):
    clear_output(wait=True)
    
    #변수 초기화
    capital = 1000 * 10000 #천만원으로 시작
    remain_cash = capital
    done = False

    for state_idx, state in enumerate(state_list):
        cnt_for_update += 1
        cnt_for_copy += 1

        #update_period 횟수가 되면 pred 모델을 학습시키고 저장한다.
        if cnt_for_update+1 == update_period:
            batch_buffer = np.array(batch_buffer, dtype=np.float64)
            batch_buffer = batch_buffer.reshape(batch_buffer.shape[0], batch_buffer.shape[2])

            reward_list = np.array(reward_list, dtype=np.float64)
            batch_list = np.hstack([batch_buffer, reward_list])
            training_data = batch_list
            
            # training_data = []
            # sample_idx = np.random.choice(batch_list.shape[0], 32)
            # for idx in sample_idx:
            #     training_data.append(batch_list[idx])
            # training_data = np.array(training_data)

            model_pred.fit(training_data[:, :-2], training_data[:, -2:], verbose=0, batch_size=32)
            model_pred.save("model_pred.h5")
            batch_buffer = [] #업데이트 한 후 미니배치(x)를 초기화한다.
            reward_list = [] #업데이트 한 후 보상값(y)을 초기화한다.
            cnt_for_update = 0
            # print("모델 업데이트")

        #특정 시점(copy_period)가 되면 q모델을 pred모델로부터 복제해 온다.
        if cnt_for_copy+1 == copy_period:
            model_q = tf.keras.models.load_model("model_pred.h5")
            cnt_for_copy = 0
            # print("모델 복제")

        #현재 스테이트의 정보를 불러온다. (60행 * 4열)
        state_data = np.array(state[:, 1:], dtype=np.float64)

        #flatten => 240행
        state_data = state_data.reshape(state_data.shape[0]*state_data.shape[1])

        #현재 수익율(=잔고)을 마지막 요소로 입력 => 241행 / 추후 액션 갯수를 더 늘리기 위해 작업해 놓는것... (매도/홀딩 액션 감안)
        state_data = np.append(state_data, remain_cash / capital)
        state_data = np.expand_dims(state_data, 0)
        batch_buffer.append(state_data) #pred 학습을 위해 먼저 미니배치 버퍼에 x를 넣어놓는다.

        #Q 모델에게 물어본다.
        pred = model_q.predict(state_data)
        action_selected = np.argmax(pred[0])
        action_name_org = action_names[action_selected]

        #exploration을 위해 에피소드 초기에는 랜덤하게 액션을 선택하게 한다.
        e = 1. / (((episode*0.6) / 100) + 1)
        if np.random.rand(1) < e:
            action_selected = random.randrange(0, 2)
        action_name = action_names[action_selected]

        #다음날의 데이터를 불러온다.
        snd_state_idx = df.loc[(df["date"] == state[-1, 0])].index[0] + 1
        sec_state_data = df.loc[snd_state_idx]

        #액션별 수익을 계산한다.
        buy_cnt_kdx = np.floor(remain_cash / sec_state_data["KODEX_OPN"])
        profit_kdx = (buy_cnt_kdx * (sec_state_data["KODEX_CLS"] - sec_state_data["KODEX_OPN"]))
        remain_cash_kdx = remain_cash + profit_kdx
        snd_profit_rate_kdx = remain_cash_kdx / capital
        reward_kdx = (snd_profit_rate_kdx - (1 - profit_rate_goal)) / (profit_rate_goal - (1-profit_rate_goal))

        buy_cnt_kdi = np.floor(remain_cash / sec_state_data["KODEX_INV_OPN"])
        profit_kdi = (buy_cnt_kdi * (sec_state_data["KODEX_INV_CLS"] - sec_state_data["KODEX_INV_OPN"]))
        remain_cash_kdi = remain_cash + profit_kdi
        snd_profit_rate_kdi = remain_cash_kdi / capital
        reward_kdi = (snd_profit_rate_kdi - (1 - profit_rate_goal)) / (profit_rate_goal - (1-profit_rate_goal))

        #액션을 취하고 액션별 수익을 반영한다. (다음날 시작 가격으로 매수 혹은 매도)
        if action_name == "KDX매수":
            profit = profit_kdx
            remain_cash = remain_cash_kdx
            reward = reward_kdx
        elif action_name == "KDI매수":
            profit = profit_kdi
            remain_cash = remain_cash_kdi
            reward = reward_kdi

        #수익율을 계산해 본다.
        snd_profit_rate = remain_cash / capital

        if state_idx == len(state_list)-2: #마지막 스테이트라면 (실제로는 마지막 스테이트 이전이지만)
            done = True
        else:
            #수익율이 상한선에 다다르면 reward는 2, 하한선에 다달았다면 reward를 0으로 주고 에피소드를 종료한다.
            if snd_profit_rate >= profit_rate_goal:
                reward = 2
                done = True
            elif snd_profit_rate <= 0.99: #하한선을 0.99로 한다
                reward = 0
                done = True
            else:
                #이틀 뒤의 데이터를 불러온다.
                trd_state_data = state_list[state_idx+2]

                #model_q에 물어봐서 이틀뒤의 가장 높은 이익을 구해 보상값을 업데이트해 준다.
                trd_state_data = trd_state_data[:, 1:]

                #flatten => 1행 240열
                trd_state_data = trd_state_data.reshape(trd_state_data.shape[0]*trd_state_data.shape[1])

                #현재 수익율을 마지막 요소로 입력 => 241행
                trd_state_data = np.append(trd_state_data, remain_cash / capital)
                trd_state_data = np.expand_dims(trd_state_data, 0)
                trd_state_data = trd_state_data.astype(float)

                trd_pred = model_q.predict(trd_state_data)
                trd_reward = np.max(trd_pred[0]) #0~1사이 값으로 출력될 것
                reward = reward + (dis * trd_reward)
                # if reward > 1: #제한을 걸어야 하나 말아야 하나...
                #     reward = 1

        if action_name == "KDX매수":
            this_reward_list = [reward, reward_kdi]
            
        elif action_name == "KDI매수":
            this_reward_list = [reward_kdx, reward]

        #보상을 reward_list에 반영한다. (y값이 될 것)
        reward_list.append(this_reward_list)

        # print("\n\n[EPISODE{}, S{} : {} → {}] {} {}".format(
        #     episode, state_idx, action_name_org, action_name, pred[0], this_reward_list), end="\r")
        print("\n\n[EPISODE{}, S{}] {} {}".format(
            episode, state_idx, pred[0], this_reward_list), end="\r")        
        print("\n잔고 : {:,d}원".format(int(remain_cash), end="\r"))

        if done is True:
            result.append({
                "EPISODE" : episode,
                "MAX. STATE" : state_idx,
                "잔고" : remain_cash,
                "수익" : remain_cash - capital,
                "수익율" : remain_cash / capital
            })
            break

    df_result = pd.DataFrame(result)
    df_result.to_excel("result.xlsx", index=False)
# Out:
# [EPISODE1, S0 : KDI → KDI] [0.4200267  0.57997334] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S1 : KDI → KDI] [0.43232813 0.56767184] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S2 : KDI → KDX] [0.44420037 0.5557996 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S3 : KDI → KDX] [0.45486948 0.5451305 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S4 : KDX → KDX] [0.5010724 0.4989276] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S5 : KDI → KDI] [0.49273288 0.5072671 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S6 : KDX → KDI] [0.5128709  0.48712912] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S7 : KDI → KDI] [0.48271286 0.51728714] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S8 : KDI → KDX] [0.49507672 0.5049233 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S9 : KDI → KDX] [0.48297358 0.5170264 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S10 : KDI → KDX] [0.4842319 0.5157681] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S11 : KDX → KDX] [0.52630997 0.47369006] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S12 : KDX → KDX] [0.5337475  0.46625254] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S13 : KDX → KDX] [0.56295514 0.4370449 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S14 : KDX → KDX] [0.54961896 0.45038107] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S15 : KDX → KDI] [0.55135566 0.4486444 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S16 : KDX → KDX] [0.5190834  0.48091662] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S17 : KDX → KDI] [0.5012338  0.49876618] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S18 : KDI → KDX] [0.49957022 0.50042975] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S19 : KDI → KDX] [0.4961045  0.50389546] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S20 : KDX → KDX] [0.50282407 0.49717593] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S21 : KDX → KDI] [0.5012598  0.49874017] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S22 : KDX → KDX] [0.5086312 0.4913687] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S23 : KDX → KDI] [0.5133851  0.48661485] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S24 : KDI → KDI] [0.49645042 0.5035496 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S25 : KDI → KDX] [0.49182492 0.508175  ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S26 : KDX → KDX] [0.5057246  0.49427542] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S27 : KDX → KDI] [0.5028928  0.49710718] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S28 : KDX → KDI] [0.51495343 0.4850466 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S29 : KDI → KDI] [0.48983592 0.5101641 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S30 : KDI → KDX] [0.4925327  0.50746727] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S31 : KDI → KDX] [0.4950552 0.5049448] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S32 : KDI → KDX] [0.4891872  0.51081276] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S33 : KDI → KDI] [0.48273966 0.5172603 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S34 : KDX → KDX] [0.5092325  0.49076748] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S35 : KDX → KDX] [0.5134638  0.48653618] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S36 : KDX → KDX] [0.50741124 0.4925888 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S37 : KDX → KDI] [0.50206286 0.49793717] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S38 : KDI → KDX] [0.48490196 0.51509804] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S39 : KDI → KDX] [0.47996545 0.5200345 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S40 : KDI → KDI] [0.46632278 0.5336772 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S41 : KDI → KDX] [0.4700295 0.5299705] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S42 : KDI → KDX] [0.46690354 0.53309643] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S43 : KDI → KDX] [0.480356 0.519644] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S44 : KDI → KDX] [0.48541537 0.51458466] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S45 : KDI → KDX] [0.47996655 0.5200335 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S46 : KDI → KDX] [0.4665558 0.5334442] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S47 : KDI → KDI] [0.4737639 0.5262361] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S48 : KDI → KDI] [0.4856233  0.51437664] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S49 : KDI → KDX] [0.49416167 0.5058384 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S50 : KDX → KDI] [0.50619996 0.49380004] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S51 : KDI → KDI] [0.49561778 0.50438225] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S52 : KDI → KDX] [0.4894394  0.51056063] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S53 : KDI → KDI] [0.48809844 0.5119015 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S54 : KDI → KDX] [0.47683066 0.52316934] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S55 : KDI → KDX] [0.4660408 0.5339592] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S56 : KDI → KDX] [0.47650754 0.52349246] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S57 : KDI → KDX] [0.48286435 0.5171357 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S58 : KDI → KDX] [0.49531186 0.5046882 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S59 : KDX → KDX] [0.5157361  0.48426387] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S60 : KDI → KDX] [0.49003994 0.50996006] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S61 : KDI → KDX] [0.48507997 0.51492006] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S62 : KDI → KDI] [0.48511654 0.51488346] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S63 : KDI → KDX] [0.47987917 0.5201208 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S64 : KDI → KDI] [0.49991125 0.50008875] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S65 : KDI → KDI] [0.4989652 0.5010348] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S66 : KDX → KDX] [0.53156084 0.46843916] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S67 : KDX → KDI] [0.52254707 0.47745293] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S68 : KDX → KDI] [0.50763464 0.4923653 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S69 : KDX → KDX] [0.506398 0.493602] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S70 : KDI → KDX] [0.48461628 0.5153837 ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S71 : KDI → KDX] [0.47491193 0.525088  ] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S72 : KDI → KDI] [0.47825384 0.52174616] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S73 : KDI → KDI] [0.48803702 0.51196295] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S74 : KDX → KDI] [0.5124081 0.4875919] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S75 : KDI → KDI] [0.4994717 0.5005283] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S76 : KDI → KDI] [0.484837   0.51516306] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S77 : KDI → KDI] [0.4792655 0.5207345] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
#
#
# [EPISODE1, S78 : KDI → KDI] [0.4755877  0.52441233] [1.1086233697185517, 0.820505]
# 잔고 : 10,000,000원
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\poscohrd\Documents\GitHub\reinforcement-learning\dqn_test_ver2.ipynb Cell 9' in <cell line: 14>()
#      <a href='vscode-notebook-cell:/c%3A/Users/poscohrd/Documents/GitHub/reinforcement-learning/dqn_test_ver2.ipynb#ch0000008?line=62'>63</a> batch_buffer.append(state_data) #pred 학습을 위해 먼저 미니배치 버퍼에 x를 넣어놓는다.
#      <a href='vscode-notebook-cell:/c%3A/Users/poscohrd/Documents/GitHub/reinforcement-learning/dqn_test_ver2.ipynb#ch0000008?line=64'>65</a> #Q 모델에게 물어본다.
# ---> <a href='vscode-notebook-cell:/c%3A/Users/poscohrd/Documents/GitHub/reinforcement-learning/dqn_test_ver2.ipynb#ch0000008?line=65'>66</a> pred = model_q.predict(state_data)
#      <a href='vscode-notebook-cell:/c%3A/Users/poscohrd/Documents/GitHub/reinforcement-learning/dqn_test_ver2.ipynb#ch0000008?line=66'>67</a> action_selected = np.argmax(pred[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/poscohrd/Documents/GitHub/reinforcement-learning/dqn_test_ver2.ipynb#ch0000008?line=67'>68</a> action_name_org = action_names[action_selected]
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\keras\engine\training.py:1758, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1749'>1750</a>   except ValueError:
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1750'>1751</a>     warnings.warn(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1751'>1752</a>         'Using Model.predict with '
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1752'>1753</a>         'MultiWorkerDistributionStrategy or TPUStrategy and '
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1753'>1754</a>         'AutoShardPolicy.FILE might lead to out-of-order result'
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1754'>1755</a>         '. Consider setting it to AutoShardPolicy.DATA.',
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1755'>1756</a>         stacklevel=2)
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1757'>1758</a> data_handler = data_adapter.get_data_handler(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1758'>1759</a>     x=x,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1759'>1760</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1760'>1761</a>     steps_per_epoch=steps,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1761'>1762</a>     initial_epoch=0,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1762'>1763</a>     epochs=1,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1763'>1764</a>     max_queue_size=max_queue_size,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1764'>1765</a>     workers=workers,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1765'>1766</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1766'>1767</a>     model=self,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1767'>1768</a>     steps_per_execution=self._steps_per_execution)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1769'>1770</a> # Container that configures and calls `tf.keras.Callback`s.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/training.py?line=1770'>1771</a> if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\keras\engine\data_adapter.py:1403, in get_data_handler(*args, **kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1400'>1401</a> if getattr(kwargs["model"], "_cluster_coordinator", None):
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1401'>1402</a>   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1402'>1403</a> return DataHandler(*args, **kwargs)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\keras\engine\data_adapter.py:1153, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1149'>1150</a>   self._steps_per_execution = steps_per_execution
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1151'>1152</a> adapter_cls = select_data_adapter(x, y)
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1152'>1153</a> self._adapter = adapter_cls(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1153'>1154</a>     x,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1154'>1155</a>     y,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1155'>1156</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1156'>1157</a>     steps=steps_per_epoch,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1157'>1158</a>     epochs=epochs - initial_epoch,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1158'>1159</a>     sample_weights=sample_weight,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1159'>1160</a>     shuffle=shuffle,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1160'>1161</a>     max_queue_size=max_queue_size,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1161'>1162</a>     workers=workers,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1162'>1163</a>     use_multiprocessing=use_multiprocessing,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1163'>1164</a>     distribution_strategy=tf.distribute.get_strategy(),
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1164'>1165</a>     model=model)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1166'>1167</a> strategy = tf.distribute.get_strategy()
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=1168'>1169</a> self._current_step = 0
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\keras\engine\data_adapter.py:325, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=321'>322</a>     flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=322'>323</a>   return flat_dataset
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=324'>325</a> indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=326'>327</a> dataset = self.slice_inputs(indices_dataset, inputs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=328'>329</a> if shuffle == "batch":
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2048, in DatasetV2.flat_map(self, map_func, name)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2013'>2014</a> def flat_map(self, map_func, name=None):
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2014'>2015</a>   """Maps `map_func` across this dataset and flattens the result.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2015'>2016</a>
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2016'>2017</a>   The type signature is:
#    (...)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2045'>2046</a>     Dataset: A `Dataset`.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2046'>2047</a>   """
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=2047'>2048</a>   return FlatMapDataset(self, map_func, name=name)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5549, in FlatMapDataset.__init__(self, input_dataset, map_func, name)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5546'>5547</a> """See `Dataset.flat_map()` for details."""
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5547'>5548</a> self._input_dataset = input_dataset
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5548'>5549</a> self._map_func = StructuredFunctionWrapper(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5549'>5550</a>     map_func, self._transformation_name(), dataset=input_dataset)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5550'>5551</a> if not isinstance(self._map_func.output_structure, DatasetSpec):
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5551'>5552</a>   raise TypeError(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5552'>5553</a>       "The `map_func` argument must return a `Dataset` object. Got "
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=5553'>5554</a>       f"{_get_type(self._map_func.output_structure)!r}.")
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4533, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4525'>4526</a>       warnings.warn(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4526'>4527</a>           "Even though the `tf.config.experimental_run_functions_eagerly` "
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4527'>4528</a>           "option is set, this option does not apply to tf.data functions. "
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4528'>4529</a>           "To force eager execution of tf.data functions, please use "
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4529'>4530</a>           "`tf.data.experimental.enable_debug_mode()`.")
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4530'>4531</a>     fn_factory = trace_tf_function(defun_kwargs)
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4532'>4533</a> self._function = fn_factory()
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4533'>4534</a> # There is no graph to add in eager mode.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4534'>4535</a> add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\eager\function.py:3244, in Function.get_concrete_function(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3234'>3235</a> def get_concrete_function(self, *args, **kwargs):
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3235'>3236</a>   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3236'>3237</a>
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3237'>3238</a>   Args:
#    (...)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3241'>3242</a>        or `tf.Tensor` or `tf.TensorSpec`.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3242'>3243</a>   """
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3243'>3244</a>   graph_function = self._get_concrete_function_garbage_collected(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3244'>3245</a>       *args, **kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3245'>3246</a>   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3246'>3247</a>   return graph_function
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\eager\function.py:3210, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3207'>3208</a>   args, kwargs = None, None
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3208'>3209</a> with self._lock:
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3209'>3210</a>   graph_function, _ = self._maybe_define_function(args, kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3210'>3211</a>   seen_names = set()
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3211'>3212</a>   captured = object_identity.ObjectIdentitySet(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3212'>3213</a>       graph_function.graph.internal_captures)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\eager\function.py:3557, in Function._maybe_define_function(self, args, kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3552'>3553</a>   return self._define_function_with_shape_relaxation(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3553'>3554</a>       args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3555'>3556</a> self._function_cache.missed.add(call_context_key)
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3556'>3557</a> graph_function = self._create_graph_function(args, kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3557'>3558</a> self._function_cache.primary[cache_key] = graph_function
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3559'>3560</a> return graph_function, filtered_flat_args
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\eager\function.py:3392, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3386'>3387</a> missing_arg_names = [
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3387'>3388</a>     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3388'>3389</a> ]
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3389'>3390</a> arg_names = base_arg_names + missing_arg_names
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3390'>3391</a> graph_function = ConcreteFunction(
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3391'>3392</a>     func_graph_module.func_graph_from_py_func(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3392'>3393</a>         self._name,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3393'>3394</a>         self._python_function,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3394'>3395</a>         args,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3395'>3396</a>         kwargs,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3396'>3397</a>         self.input_signature,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3397'>3398</a>         autograph=self._autograph,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3398'>3399</a>         autograph_options=self._autograph_options,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3399'>3400</a>         arg_names=arg_names,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3400'>3401</a>         override_flat_arg_shapes=override_flat_arg_shapes,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3401'>3402</a>         capture_by_value=self._capture_by_value),
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3402'>3403</a>     self._function_attributes,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3403'>3404</a>     function_spec=self.function_spec,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3404'>3405</a>     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3405'>3406</a>     # scope. This is not the default behavior since it gets used in some
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3406'>3407</a>     # places (like Keras) where the FuncGraph lives longer than the
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3407'>3408</a>     # ConcreteFunction.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3408'>3409</a>     shared_func_graph=False)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/eager/function.py?line=3409'>3410</a> return graph_function
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\func_graph.py:1143, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1139'>1140</a> else:
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1140'>1141</a>   _, original_func = tf_decorator.unwrap(python_func)
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1142'>1143</a> func_outputs = python_func(*func_args, **func_kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1144'>1145</a> # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1145'>1146</a> # TensorArrays and `None`s.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1146'>1147</a> func_outputs = nest.map_structure(convert, func_outputs,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1147'>1148</a>                                   expand_composites=True)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4510, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4503'>4504</a> @eager_function.defun_with_attributes(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4504'>4505</a>     input_signature=structure.get_flat_tensor_specs(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4505'>4506</a>         self._input_structure),
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4506'>4507</a>     autograph=False,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4507'>4508</a>     attributes=defun_kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4508'>4509</a> def wrapped_fn(*args):  # pylint: disable=missing-docstring
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4509'>4510</a>   ret = wrapper_helper(*args)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4510'>4511</a>   ret = structure.to_tensor_list(self._output_structure, ret)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4511'>4512</a>   return [ops.convert_to_tensor(t) for t in ret]
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4440, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4437'>4438</a> if not _should_unpack(nested_args):
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4438'>4439</a>   nested_args = (nested_args,)
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4439'>4440</a> ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4440'>4441</a> if _should_pack(ret):
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/data/ops/dataset_ops.py?line=4441'>4442</a>   ret = tuple(ret)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:696, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=693'>694</a> try:
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=694'>695</a>   with conversion_ctx:
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=695'>696</a>     return converted_call(f, args, kwargs, options=options)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=696'>697</a> except Exception as e:  # pylint:disable=broad-except
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=697'>698</a>   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:383, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=379'>380</a>   return _call_unconverted(f, args, kwargs, options)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=381'>382</a> if not options.user_requested and conversion.is_allowlisted(f):
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=382'>383</a>   return _call_unconverted(f, args, kwargs, options)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=384'>385</a> # internal_convert_user_code is for example turned off when issuing a dynamic
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=385'>386</a> # call conversion from generated code while in nonrecursive mode. In that
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=386'>387</a> # case we evidently don't want to recurse, but we still have to convert
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=387'>388</a> # things like builtins.
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=388'>389</a> if not options.internal_convert_user_code:
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:464, in _call_unconverted(f, args, kwargs, options, update_cache)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=460'>461</a>   return f.__self__.call(args, kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=462'>463</a> if kwargs is not None:
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=463'>464</a>   return f(*args, **kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/autograph/impl/api.py?line=464'>465</a> return f(*args)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\keras\engine\data_adapter.py:311, in TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices(indices)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=308'>309</a> num_in_full_batch = num_full_batches * batch_size
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=309'>310</a> first_k_indices = tf.slice(indices, [0], [num_in_full_batch])
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=310'>311</a> first_k_indices = tf.reshape(
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=311'>312</a>     first_k_indices, [num_full_batches, batch_size])
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=313'>314</a> flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/keras/engine/data_adapter.py?line=314'>315</a> if self._partial_batch_size:
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\util\dispatch.py:1096, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/dispatch.py?line=1093'>1094</a> # Fallback dispatch system (dispatch v1):
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/dispatch.py?line=1094'>1095</a> try:
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/dispatch.py?line=1095'>1096</a>   return dispatch_target(*args, **kwargs)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/dispatch.py?line=1096'>1097</a> except (TypeError, ValueError):
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/dispatch.py?line=1097'>1098</a>   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/dispatch.py?line=1098'>1099</a>   # TypeError, when given unexpected types.  So we need to catch both.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/dispatch.py?line=1099'>1100</a>   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\ops\array_ops.py:197, in reshape(tensor, shape, name)
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=60'>61</a> @tf_export("reshape", v1=["reshape", "manip.reshape"])
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=61'>62</a> @dispatch.add_dispatch_support
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=62'>63</a> def reshape(tensor, shape, name=None):  # pylint: disable=redefined-outer-name
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=63'>64</a>   r"""Reshapes a tensor.
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=64'>65</a>
#      <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=65'>66</a>   Given `tensor`, this operation returns a new `tf.Tensor` that has the same
#    (...)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=194'>195</a>     A `Tensor`. Has the same type as `tensor`.
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=195'>196</a>   """
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=196'>197</a>   result = gen_array_ops.reshape(tensor, shape, name)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=197'>198</a>   tensor_util.maybe_set_static_shape(result, shape)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/array_ops.py?line=198'>199</a>   return result
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:8545, in reshape(tensor, shape, name)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=8542'>8543</a>     pass  # Add nodes to the TensorFlow graph.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=8543'>8544</a> # Add nodes to the TensorFlow graph.
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=8544'>8545</a> _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=8545'>8546</a>       "Reshape", tensor=tensor, shape=shape, name=name)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=8546'>8547</a> _result = _outputs[:]
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/ops/gen_array_ops.py?line=8547'>8548</a> if _execute.must_record_gradient():
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\op_def_library.py:492, in _apply_op_helper(op_type_name, name, **keywords)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=489'>490</a> inferred = None
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=490'>491</a> try:
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=491'>492</a>   inferred = ops.convert_to_tensor(
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=492'>493</a>       values, name=input_arg.name, as_ref=input_arg.is_ref)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=493'>494</a> except TypeError as err:
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=494'>495</a>   # When converting a python object such as a list of Dimensions, we
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=495'>496</a>   # need a dtype to be specified, thus tensor conversion may throw
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=496'>497</a>   # an exception which we will ignore and try again below.
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=497'>498</a>   pass
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\profiler\trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/profiler/trace.py?line=160'>161</a>   with Trace(trace_name, **trace_kwargs):
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/profiler/trace.py?line=161'>162</a>     return func(*args, **kwargs)
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/profiler/trace.py?line=162'>163</a> return func(*args, **kwargs)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\ops.py:1621, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1615'>1616</a>       raise TypeError("convert_to_tensor did not convert to "
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1616'>1617</a>                       "the preferred dtype: %s vs %s " %
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1617'>1618</a>                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1619'>1620</a> if ret is None:
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1620'>1621</a>   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1622'>1623</a> if ret is NotImplemented:
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1623'>1624</a>   continue
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\constant_op.py:347, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=343'>344</a> def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=344'>345</a>                                          as_ref=False):
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=345'>346</a>   _ = as_ref
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=346'>347</a>   return constant(v, dtype=dtype, name=name)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\constant_op.py:271, in constant(value, dtype, shape, name)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=173'>174</a> @tf_export("constant", v1=[])
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=174'>175</a> def constant(value, dtype=None, shape=None, name="Const"):
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=175'>176</a>   """Creates a constant tensor from a tensor-like object.
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=176'>177</a>
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=177'>178</a>   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=268'>269</a>     ValueError: if called on a symbolic tensor.
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=269'>270</a>   """
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=270'>271</a>   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=271'>272</a>                         allow_broadcast=True)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\constant_op.py:293, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=290'>291</a> dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=291'>292</a> attrs = {"value": tensor_value, "dtype": dtype_value}
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=292'>293</a> const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=293'>294</a>     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=295'>296</a> if op_callbacks.should_invoke_op_callbacks():
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=296'>297</a>   # TODO(b/147670703): Once the special-op creation code paths
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=297'>298</a>   # are unified. Remove this `if` block.
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=298'>299</a>   callback_outputs = op_callbacks.invoke_op_callbacks(
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/constant_op.py?line=299'>300</a>       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\func_graph.py:689, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=686'>687</a>   inp = self.capture(inp)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=687'>688</a>   captured_inputs.append(inp)
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=688'>689</a> return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=689'>690</a>     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/func_graph.py?line=690'>691</a>     compute_device)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\ops.py:3697, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3693'>3694</a> # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3694'>3695</a> # Session.run call cannot occur between creating and mutating the op.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3695'>3696</a> with self._mutation_lock():
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3696'>3697</a>   ret = Operation(
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3697'>3698</a>       node_def,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3698'>3699</a>       self,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3699'>3700</a>       inputs=inputs,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3700'>3701</a>       output_types=dtypes,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3701'>3702</a>       control_inputs=control_inputs,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3702'>3703</a>       input_types=input_types,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3703'>3704</a>       original_op=self._default_original_op,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3704'>3705</a>       op_def=op_def)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3705'>3706</a>   self._create_op_helper(ret, compute_device=compute_device)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=3706'>3707</a> return ret
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\ops.py:2097, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=2094'>2095</a>   if op_def is None:
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=2095'>2096</a>     op_def = self._graph._get_op_def(node_def.op)
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=2096'>2097</a>   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=2097'>2098</a>                             control_input_ops, op_def)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=2098'>2099</a>   name = compat.as_str(node_def.name)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=2100'>2101</a> self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\poscohrd\hrdkdh\venv\venv_tf\lib\site-packages\tensorflow\python\framework\ops.py:1936, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1931'>1932</a>   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1932'>1933</a>                                          serialized)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1934'>1935</a> try:
# -> <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1935'>1936</a>   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1936'>1937</a> except errors.InvalidArgumentError as e:
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1937'>1938</a>   # Convert to ValueError for backwards compatibility.
#    <a href='file:///c%3A/Users/poscohrd/hrdkdh/venv/venv_tf/lib/site-packages/tensorflow/python/framework/ops.py?line=1938'>1939</a>   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %% [markdown]
# # 추론 / 테스트 데이터에 적용

# %%
#2020년 데이터로 추론해 본다.
df_test = df_kospi.merge(df_kodex, how="right", on="date")
df_test = df_test.merge(df_kodex_inv, how="left", on="date")
df_test.dropna(inplace=True)
df_test.sort_values("date", inplace=True)
df_test.reset_index(drop=True, inplace=True)

df_test["date"] = pd.to_datetime(df_test["date"])
df_test = df_test[(df_test["date"] >= "2020-01-01") & (df_test["date"] <= "2020-12-31")]
df_test.reset_index(drop=True, inplace=True)
df_test
# Out:
#           date    KOSPI  KOSPI_START  KOSPI_HIGH  KOSPI_LOW  KODEX_CLS  \
# 0   2020-01-02  2175.17      2201.21     2202.32    2171.84      22235
# 1   2020-01-03  2176.46      2192.58     2203.38    2165.39      22230
# 2   2020-01-06  2155.07      2154.97     2164.42    2149.95      22020
# 3   2020-01-07  2175.54      2166.60     2181.62    2164.27      22195
# 4   2020-01-08  2151.31      2156.27     2162.32    2137.72      21960
# ..         ...      ...          ...         ...        ...        ...
# 236 2020-12-23  2759.82      2737.74     2769.08    2716.28      27635
# 237 2020-12-24  2806.86      2762.60     2812.16    2762.60      28095
# 238 2020-12-28  2808.60      2820.95     2834.59    2799.56      28125
# 239 2020-12-29  2820.51      2810.55     2823.44    2792.06      28595
# 240 2020-12-30  2873.47      2820.36     2878.21    2809.35      29260
#
#      KODEX_OPN  KODEX_GAP  KODEX_INV_CLS  KODEX_INV_OPN  KODEX_INV_GAP
# 0        22460        225         6425.0         6350.0          -75.0
# 1        22400        170         6430.0         6365.0          -65.0
# 2        21995        -25         6480.0         6485.0            5.0
# 3        22100        -95         6410.0         6450.0           40.0
# 4        22090        130         6455.0         6460.0            5.0
# ..         ...        ...            ...            ...            ...
# 236      27525       -110         4545.0         4595.0           50.0
# 237      27700       -395         4450.0         4535.0           85.0
# 238      28245        120         4435.0         4420.0          -15.0
# 239      28505        -90         4365.0         4395.0           30.0
# 240      28675       -585         4255.0         4375.0          120.0
#
# [241 rows x 11 columns]

# %%
state_list = []
for idx in range(len(df_test)):
    if idx > 59:
        this_mat = df_test.iloc[idx-60:idx, 0:5].to_numpy()
        for col_idx in range(1, this_mat.shape[1]):
            this_arr = this_mat[:, col_idx]
            max_val = max(this_arr)
            min_val = min(this_arr)
            for row_idx, val in enumerate(this_arr):
                new_val = (val - min_val) / (max_val - min_val)
                this_mat[row_idx, col_idx] = new_val
        state_list.append(this_mat)

state_list = np.array(state_list)
state_list.shape

#6개열 : date, KOSPI, KOSPI_START, KOSPI_HIGH, KOSPI_LOW, CAPITAL
# Out:
# (181, 60, 5)

# %%
model = tf.keras.models.load_model("model_pred_1.2.h5")
action_names = ["KDX매수", "KDI매수"]
capital = 1000 * 10000
remain_cash = capital
result = []
for state_idx, state in enumerate(state_list):
    #현재 스테이트의 정보를 불러온다. (60행 * 4열)
    state_data = np.array(state[:, 1:], dtype=np.float64)

    #flatten => 240행
    state_data = state_data.reshape(state_data.shape[0]*state_data.shape[1])

    #현재 수익율(=잔고)을 마지막 요소로 입력 => 241행 / 추후 액션 갯수를 더 늘리기 위해 작업해 놓는것... (매도/홀딩 액션 감안)
    state_data = np.append(state_data, remain_cash / capital)
    state_data = np.expand_dims(state_data, 0)

    #Q 모델에게 물어본다.
    pred = model.predict(state_data)
    action_selected = np.argmax(pred[0])
    action_name = action_names[action_selected]
    # print("STATE {} : {}".format(state_idx, action_name))

    #다음날의 데이터를 불러온다.
    snd_state_idx = df_test.loc[(df_test["date"] == state[-1, 0])].index[0] + 1
    sec_state_data = df_test.loc[snd_state_idx]

    #액션별 수익을 계산한다.
    buy_cnt_kdx = np.floor(remain_cash / sec_state_data["KODEX_OPN"])
    profit_kdx = (buy_cnt_kdx * (sec_state_data["KODEX_CLS"] - sec_state_data["KODEX_OPN"]))
    remain_cash_kdx = remain_cash + profit_kdx

    buy_cnt_kdi = np.floor(remain_cash / sec_state_data["KODEX_INV_OPN"])
    profit_kdi = (buy_cnt_kdi * (sec_state_data["KODEX_INV_CLS"] - sec_state_data["KODEX_INV_OPN"]))
    remain_cash_kdi = remain_cash + profit_kdi

    #액션을 취하고 액션별 수익을 반영한다. (다음날 시작 가격으로 매수 혹은 매도)
    if action_name == "KDX매수":
        profit = profit_kdx
        remain_cash = remain_cash_kdx
    elif action_name == "KDI매수":
        profit = profit_kdi
        remain_cash = remain_cash_kdi

    #수익율을 계산해 본다.
    snd_profit_rate = remain_cash / capital

    result.append({
        "STATE" : state_idx,
        "잔고" : remain_cash,
        "수익" : remain_cash - capital,
        "수익율" : remain_cash / capital
    })

df_result = pd.DataFrame(result)
df_result.to_excel("result_test.xlsx", index=False)
df_result
# Out:
# 2022-04-13 07:55:49.627124: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#      STATE          잔고         수익       수익율
# 0        0  10376485.0   376485.0  1.037648
# 1        1  10156705.0   156705.0  1.015670
# 2        2  10170025.0   170025.0  1.017003
# 3        3   9833525.0  -166475.0  0.983352
# 4        4   9840375.0  -159625.0  0.984038
# ..     ...         ...        ...       ...
# 176    176   8919360.0 -1080640.0  0.891936
# 177    177   8752250.0 -1247750.0  0.875225
# 178    178   8781950.0 -1218050.0  0.878195
# 179    179   8722010.0 -1277990.0  0.872201
# 180    180   8899850.0 -1100150.0  0.889985
#
# [181 rows x 4 columns]

# %%
df_result["잔고"].plot()
# Out:
# <AxesSubplot:>
